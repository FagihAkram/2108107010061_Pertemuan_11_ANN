# %%
# Mengimpor library yang diperlukan
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
labelencoder = LabelEncoder()

# Impor dataset
dataset = pd.read_csv('dataset.csv')
datasetc = pd.read_csv('dataset.csv')

# %%
columns_to_drop = ['user-id', 'user-gender', 'user-nationality', 'user-knowledge', 'user-loyalty', 'user-loan',
                   'user-riskAversion', 'user-marital', 'product-type', 'product-risk', 'transaction-id', 'product-yield']

datasetc.drop(columns=columns_to_drop, inplace=True)
datasetc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user-age         999 non-null    int64
#  1   user-income      999 non-null    int64
#  2   user-savings     999 non-null    int64
#  3   user-properties  999 non-null    int64
#  4   user-dependents  999 non-null    int64
#  5   user-pension     999 non-null    int64
#  6   product-term     999 non-null    int64
#  7   year             999 non-null    int64
#  8   month            999 non-null    int64
#  9   score            999 non-null    float64
# dtypes: float64(1), int64(9)
# memory usage: 78.2 KB

# %%
# Menghitung matriks korelasi
correlation_matrix = datasetc.corr()

# Plot heatmap untuk matriks korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user-id            999 non-null    object
#  1   user-age           999 non-null    int64
#  2   user-gender        999 non-null    object
#  3   user-nationality   999 non-null    object
#  4   user-knowledge     999 non-null    object
#  5   user-loyalty       999 non-null    object
#  6   user-loan          999 non-null    object
#  7   user-income        999 non-null    int64
#  8   user-savings       999 non-null    int64
#  9   user-properties    999 non-null    int64
#  10  user-riskAversion  999 non-null    object
#  11  user-marital       999 non-null    object
#  12  user-dependents    999 non-null    int64
#  13  user-pension       999 non-null    int64
#  14  product-type       999 non-null    object
#  15  product-risk       999 non-null    object
#  16  product-term       999 non-null    int64
#  17  product-yield      999 non-null    object
#  18  transaction-id     999 non-null    object
#  19  year               999 non-null    int64
#  20  month              999 non-null    int64
#  21  score              999 non-null    float64
# dtypes: float64(1), int64(9), object(12)
# memory usage: 171.8+ KB

# %%
# Identifikasi data dan label
X = dataset.iloc[:, [1, 2, 7, 8, 9]].values #fitur
y = LabelEncoder().fit_transform(dataset.iloc[:, 6].values)

# %%
import numpy as np

# Menghitung jumlah kelas dalam variabel target y
classes = np.unique(y)
num_classes = len(classes)

print(f"Jumlah kelas: {num_classes}")
print(f"Kelas yang ada: {classes}")
# Out:
# Jumlah kelas: 2
# Kelas yang ada: [0 1]

# %%
# Mengonversi data kategori jenis kelamin menjadi numerik
X[:, 1] = labelencoder.fit_transform(X[:, 1])


# Membagi data ke test dan training set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Mengimpor library Keras dan turunannya
# Sekarang menggunakan TensorFlow 2.0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Inisialisasi ANN
MesinKlasifikasi = Sequential()

# Menambah input layer dan hidden layer pertama
MesinKlasifikasi.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
# Menambah hidden layer kedua
MesinKlasifikasi.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
# Menambah output layer
MesinKlasifikasi.add(Dense(units = 2, kernel_initializer = 'uniform', activation = 'softmax'))

# Meenjalankan ANN
MesinKlasifikasi.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# Fitting ANN ke training set
MesinKlasifikasi.fit(X_train, y_train, batch_size = 10, epochs = 100)

# Memprediksi hasil test sety
y_pred = MesinKlasifikasi.predict(X_test)
y_pred = (y_pred > 0.5)

# # Membuat confusion matrix
# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(y_test, y_pred)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 2s 5ms/step - loss: 0.6687 - accuracy: 0.7897
# Epoch 2/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5964 - accuracy: 0.7897
# Epoch 3/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5271 - accuracy: 0.7897
# Epoch 4/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5106 - accuracy: 0.7897
# Epoch 5/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5099 - accuracy: 0.7897
# Epoch 6/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5078 - accuracy: 0.7897
# Epoch 7/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5071 - accuracy: 0.7897
# Epoch 8/100
# 80/80 [==============================] - 1s 7ms/step - loss: 0.5067 - accuracy: 0.7897
# Epoch 9/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5063 - accuracy: 0.7897
# Epoch 10/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5061 - accuracy: 0.7897
# Epoch 11/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.7897
# Epoch 12/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5059 - accuracy: 0.7897
# Epoch 13/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5057 - accuracy: 0.7897
# Epoch 14/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5056 - accuracy: 0.7897
# Epoch 15/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5051 - accuracy: 0.7897
# Epoch 16/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.7897
# Epoch 17/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5047 - accuracy: 0.7897
# Epoch 18/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7897
# Epoch 19/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.5045 - accuracy: 0.7897
# Epoch 20/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7897
# Epoch 21/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5049 - accuracy: 0.7897
# Epoch 22/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5046 - accuracy: 0.7897
# Epoch 23/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5041 - accuracy: 0.7897
# Epoch 24/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7897
# Epoch 25/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.5042 - accuracy: 0.7897
# Epoch 26/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.5039 - accuracy: 0.7897
# Epoch 27/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.5040 - accuracy: 0.7897
# Epoch 28/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.5044 - accuracy: 0.7897
# Epoch 29/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.5041 - accuracy: 0.7897
# Epoch 30/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5042 - accuracy: 0.7897
# Epoch 31/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5047 - accuracy: 0.7897
# Epoch 32/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5041 - accuracy: 0.7897
# Epoch 33/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5046 - accuracy: 0.7897
# Epoch 34/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7897
# Epoch 35/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5043 - accuracy: 0.7897
# Epoch 36/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5044 - accuracy: 0.7897
# Epoch 37/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5038 - accuracy: 0.7897
# Epoch 38/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5042 - accuracy: 0.7897
# Epoch 39/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5042 - accuracy: 0.7897
# Epoch 40/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.7897
# Epoch 41/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7897
# Epoch 42/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5045 - accuracy: 0.7897
# Epoch 43/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5038 - accuracy: 0.7897
# Epoch 44/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7897
# Epoch 45/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5040 - accuracy: 0.7897
# Epoch 46/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5042 - accuracy: 0.7897
# Epoch 47/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7897
# Epoch 48/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.7897
# Epoch 49/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5038 - accuracy: 0.7897
# Epoch 50/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5037 - accuracy: 0.7897
# Epoch 51/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5034 - accuracy: 0.7897
# Epoch 52/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7897
# Epoch 53/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5038 - accuracy: 0.7897
# Epoch 54/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5038 - accuracy: 0.7897
# Epoch 55/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5047 - accuracy: 0.7897
# Epoch 56/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.5035 - accuracy: 0.7897
# Epoch 57/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5037 - accuracy: 0.7897
# Epoch 58/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5037 - accuracy: 0.7897
# Epoch 59/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7897
# Epoch 60/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.7897
# Epoch 61/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5033 - accuracy: 0.7897
# Epoch 62/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5034 - accuracy: 0.7897
# Epoch 63/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7897
# Epoch 64/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5037 - accuracy: 0.7897
# Epoch 65/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5033 - accuracy: 0.7897
# Epoch 66/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5035 - accuracy: 0.7897
# Epoch 67/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5033 - accuracy: 0.7897
# Epoch 68/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5045 - accuracy: 0.7897
# Epoch 69/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5037 - accuracy: 0.7897
# Epoch 70/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7897
# Epoch 71/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.7897
# Epoch 72/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7897
# Epoch 73/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.7897
# Epoch 74/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5034 - accuracy: 0.7897
# Epoch 75/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5031 - accuracy: 0.7897
# Epoch 76/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5035 - accuracy: 0.7897
# Epoch 77/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5032 - accuracy: 0.7897
# Epoch 78/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.7897
# Epoch 79/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5033 - accuracy: 0.7897
# Epoch 80/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5032 - accuracy: 0.7897
# Epoch 81/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.7897
# Epoch 82/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.7897
# Epoch 83/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.7897
# Epoch 84/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.7897
# Epoch 85/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5025 - accuracy: 0.7897
# Epoch 86/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5025 - accuracy: 0.7897
# Epoch 87/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5024 - accuracy: 0.7897
# Epoch 88/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5022 - accuracy: 0.7897
# Epoch 89/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 0.7897
# Epoch 90/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5024 - accuracy: 0.7897
# Epoch 91/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5015 - accuracy: 0.7897
# Epoch 92/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5012 - accuracy: 0.7897
# Epoch 93/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5014 - accuracy: 0.7897
# Epoch 94/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5019 - accuracy: 0.7897
# Epoch 95/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5007 - accuracy: 0.7897
# Epoch 96/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5006 - accuracy: 0.7897
# Epoch 97/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.5008 - accuracy: 0.7897
# Epoch 98/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5007 - accuracy: 0.7897
# Epoch 99/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5003 - accuracy: 0.7897
# Epoch 100/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5000 - accuracy: 0.7897
# 7/7 [==============================] - 0s 3ms/step

# %%
# Memprediksi hasil test set
y_pred = MesinKlasifikasi.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Mengambil indeks kelas dengan probabilitas tertinggi
y_test_classes = y_test 

# Membuat confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test_classes, y_pred_classes)
# Out:
# 7/7 [==============================] - 0s 6ms/step

# %%
# Menghitung akurasi model
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print(f"Akurasi model: {accuracy * 100:.2f}%")
# Out:
# Akurasi model: 80.00%

# %%
# Menampilkan visualisasi confusion matrix
print("Confusion Matrix:")
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Confusion Matrix:
